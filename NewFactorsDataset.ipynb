# %%
#defining variables

#population defined in millions
#GDP defined in billions USD
#Size defined in square miles
DEPopulation2015 = 38.01
DEPopulation2016 = 37.97
DEGDP2015 = 3383.091
DEGDP2016 = 3496.606
DESize = 137988

ATPopulation2015 = 38.01
ATPopulation2016 = 37.97 
ATGDP2015 = 381.998
ATGDP2016 = 394.215
ATSize = 32386

FRPopulation2015 = 38.01
FRPopulation2016 = 37.97
FRGDP2015 = 2439.435
FRGDP2016 = 2466.152
FRSize = 248573

PLPopulation2015 = 38.01
PLPopulation2016 = 37.97
PLGDP2015 = 477.568
PLGDP2016 = 471.843
PLSize = 120726

DKPopulation2015 = 38.01
DKPopulation2016 = 37.97 
DKGDP2015 = 302.673
DKGDP2016 = 311.988
DKSize = 16577

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
windgenDE = pd.read_csv("data/time_series_60min_singleindex.csv",
                        usecols=(lambda s: s.startswith('utc') | 
                                 s. startswith('DE_wind_generation')),
                        parse_dates=[0], index_col=0)

windgenAT = pd.read_csv("data/time_series_60min_singleindex.csv",
                        usecols=(lambda s: s.startswith('utc') | 
                                 s. startswith('AT_wind_onshore_generation')),
                        parse_dates=[0], index_col=0)

windgenFR = pd.read_csv("data/time_series_60min_singleindex.csv",
                        usecols=(lambda s: s.startswith('utc') | 
                                 s. startswith('FR_wind_onshore_generation')),
                        parse_dates=[0], index_col=0)

windgenPL = pd.read_csv("data/time_series_60min_singleindex.csv",
                        usecols=(lambda s: s.startswith('utc') | 
                                 s. startswith('PL_wind_onshore_generation')),
                        parse_dates=[0], index_col=0)

windgenDK = pd.read_csv("data/time_series_60min_singleindex.csv",
                        usecols=(lambda s: s.startswith('utc') | 
                                 s. startswith('DK_wind_onshore_generation')),
                        parse_dates=[0], index_col=0)

# %%
windspeedDE = pd.read_csv("data/weather_data.csv",
                usecols=(lambda s: s.startswith('utc') | 
                         s.startswith('DE_windspeed')),
                parse_dates=[0], index_col=0)

windspeedAT = pd.read_csv("data/weather_data.csv",
                usecols=(lambda s: s.startswith('utc') | 
                         s.startswith('AT_windspeed')),
                parse_dates=[0], index_col=0)


windspeedFR = pd.read_csv("data/weather_data.csv",
                usecols=(lambda s: s.startswith('utc') | 
                         s.startswith('FR_windspeed')),
                parse_dates=[0], index_col=0)

windspeedPL = pd.read_csv("data/weather_data.csv",
                usecols=(lambda s: s.startswith('utc') | 
                         s.startswith('PL_windspeed')),
                parse_dates=[0], index_col=0)

windspeedDK = pd.read_csv("data/weather_data.csv",
                usecols=(lambda s: s.startswith('utc') | 
                         s.startswith('DK_windspeed')),
                parse_dates=[0], index_col=0)

# %%
# start_remove = pd.to_datetime('2016-01-01')
# end_remove = pd.to_datetime('2017-01-01')

# start_test = pd.to_datetime('2015-01-01')
# end_test = pd.to_datetime('2016-01-01')

# %%
start_remove = pd.to_datetime('2016-01-01', utc = True)
end_remove = pd.to_datetime('2017-01-01', utc = True)

start_test = pd.to_datetime('2015-01-01', utc = True)
end_test = pd.to_datetime('2016-01-01', utc = True)

# %%
windspeedtrainDE = windspeedDE.loc[(windspeedDE.index >= start_remove) & (windspeedDE.index < end_remove)]
windgenerationtrainDE = windgenDE.loc[(windgenDE.index >= start_remove) & (windgenDE.index < end_remove)]

windspeedtestDE = windspeedDE.loc[(windspeedDE.index >= start_test) & (windspeedDE.index < end_test)]
windgenerationtestDE = windgenDE.loc[(windgenDE.index >= start_test) & (windgenDE.index < end_test)]

# %%
windspeedtrainAT = windspeedAT.loc[(windspeedAT.index >= start_remove) & (windspeedAT.index < end_remove)]
windgenerationtrainAT = windgenAT.loc[(windgenAT.index >= start_remove) & (windgenAT.index < end_remove)]

windspeedtestAT = windspeedAT.loc[(windspeedAT.index >= start_test) & (windspeedAT.index < end_test)]
windgenerationtestAT = windgenAT.loc[(windgenAT.index >= start_test) & (windgenAT.index < end_test)]

# %%
windspeedtrainFR = windspeedFR.loc[(windspeedFR.index >= start_remove) & (windspeedFR.index < end_remove)]
windgenerationtrainFR = windgenFR.loc[(windgenFR.index >= start_remove) & (windgenFR.index < end_remove)]

windspeedtestFR = windspeedFR.loc[(windspeedFR.index >= start_test) & (windspeedFR.index < end_test)]
windgenerationtestFR = windgenFR.loc[(windgenFR.index >= start_test) & (windgenFR.index < end_test)]

# %%
windspeedtrainPL = windspeedPL.loc[(windspeedPL.index >= start_remove) & (windspeedPL.index < end_remove)]
windgenerationtrainPL = windgenPL.loc[(windgenPL.index >= start_remove) & (windgenPL.index < end_remove)]

windspeedtestPL = windspeedPL.loc[(windspeedPL.index >= start_test) & (windspeedPL.index < end_test)]
windgenerationtestPL = windgenPL.loc[(windgenPL.index >= start_test) & (windgenPL.index < end_test)]

# %%
windspeedtrainDK = windspeedDK.loc[(windspeedDK.index >= start_remove) & (windspeedDK.index < end_remove)]
windgenerationtrainDK = windgenDK.loc[(windgenDK.index >= start_remove) & (windgenDK.index < end_remove)]

windspeedtestDK = windspeedDK.loc[(windspeedDK.index >= start_test) & (windspeedDK.index < end_test)]
windgenerationtestDK = windgenDK.loc[(windgenDK.index >= start_test) & (windgenDK.index < end_test)]

# %%
DEPopulation2015Array = np.zeros(8760)
DEPopulation2015Array.fill(DEPopulation2015)
windspeedtestDE['Population'] = DEPopulation2015Array
DEPopulation2016Array = np.zeros(8784)
DEPopulation2016Array.fill(DEPopulation2016)
windspeedtrainDE['Population'] = DEPopulation2016Array

DEGDP2015Array = np.zeros(8760)
DEGDP2015Array.fill(DEGDP2015)
windspeedtestDE['GDP'] = DEGDP2015Array
DEGDP2016Array = np.zeros(8784)
DEGDP2016Array.fill(DEGDP2016)
windspeedtrainDE['GDP'] = DEGDP2016Array

DESizeTestArray = np.zeros(8760)
DESizeTestArray.fill(DESize)
windspeedtestDE['Size'] = DESizeTestArray
DESizeTrainArray = np.zeros(8784)
DESizeTrainArray.fill(DESize)
windspeedtrainDE['Size'] = DESizeTrainArray
# Out:
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ATPopulation2015Array = np.zeros(8760)
ATPopulation2015Array.fill(ATPopulation2015)
windspeedtestAT['Population'] = ATPopulation2015Array
ATPopulation2016Array = np.zeros(8784)
ATPopulation2016Array.fill(ATPopulation2016)
windspeedtrainAT['Population'] = ATPopulation2016Array

ATGDP2015Array = np.zeros(8760)
ATGDP2015Array.fill(ATGDP2015)
windspeedtestAT['GDP'] = ATGDP2015Array
ATGDP2016Array = np.zeros(8784)
ATGDP2016Array.fill(ATGDP2016)
windspeedtrainAT['GDP'] = ATGDP2016Array

ATSizeTestArray = np.zeros(8760)
ATSizeTestArray.fill(ATSize)
windspeedtestAT['Size'] = ATSizeTestArray
ATSizeTrainArray = np.zeros(8784)
ATSizeTrainArray.fill(ATSize)
windspeedtrainAT['Size'] = ATSizeTrainArray
# Out:
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
FRPopulation2015Array = np.zeros(8760)
FRPopulation2015Array.fill(FRPopulation2015)
windspeedtestFR['Population'] = FRPopulation2015Array
FRPopulation2016Array = np.zeros(8784)
FRPopulation2016Array.fill(FRPopulation2016)
windspeedtrainFR['Population'] = FRPopulation2016Array

FRGDP2015Array = np.zeros(8760)
FRGDP2015Array.fill(FRGDP2015)
windspeedtestFR['GDP'] = FRGDP2015Array
FRGDP2016Array = np.zeros(8784)
FRGDP2016Array.fill(FRGDP2016)
windspeedtrainFR['GDP'] = FRGDP2016Array

FRSizeTestArray = np.zeros(8760)
FRSizeTestArray.fill(FRSize)
windspeedtestFR['Size'] = FRSizeTestArray
FRSizeTrainArray = np.zeros(8784)
FRSizeTrainArray.fill(FRSize)
windspeedtrainFR['Size'] = FRSizeTrainArray
# Out:
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
PLPopulation2015Array = np.zeros(8760)
PLPopulation2015Array.fill(PLPopulation2015)
windspeedtestPL['Population'] = PLPopulation2015Array
PLPopulation2016Array = np.zeros(8784)
PLPopulation2016Array.fill(PLPopulation2016)
windspeedtrainPL['Population'] = PLPopulation2016Array

PLGDP2015Array = np.zeros(8760)
PLGDP2015Array.fill(PLGDP2015)
windspeedtestPL['GDP'] = PLGDP2015Array
PLGDP2016Array = np.zeros(8784)
PLGDP2016Array.fill(PLGDP2016)
windspeedtrainPL['GDP'] = PLGDP2016Array

PLSizeTestArray = np.zeros(8760)
PLSizeTestArray.fill(PLSize)
windspeedtestPL['Size'] = PLSizeTestArray
PLSizeTrainArray = np.zeros(8784)
PLSizeTrainArray.fill(PLSize)
windspeedtrainPL['Size'] = PLSizeTrainArray
# Out:
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
DKPopulation2015Array = np.zeros(8760)
DKPopulation2015Array.fill(DKPopulation2015)
windspeedtestDK['Population'] = DKPopulation2015Array
DKPopulation2016Array = np.zeros(8784)
DKPopulation2016Array.fill(DKPopulation2016)
windspeedtrainDK['Population'] = DKPopulation2016Array

DKGDP2015Array = np.zeros(8760)
DKGDP2015Array.fill(DKGDP2015)
windspeedtestDK['GDP'] = DKGDP2015Array
DKGDP2016Array = np.zeros(8784)
DKGDP2016Array.fill(DKGDP2016)
windspeedtrainDK['GDP'] = DKGDP2016Array

DKSizeTestArray = np.zeros(8760)
DKSizeTestArray.fill(DKSize)
windspeedtestDK['Size'] = DKSizeTestArray
DKSizeTrainArray = np.zeros(8784)
DKSizeTrainArray.fill(DKSize)
windspeedtrainDK['Size'] = DKSizeTrainArray
# Out:
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\hong8\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
windspeedtrainDK
# Out:
#                            DK_windspeed_10m  Population      GDP     Size
# utc_timestamp
# 2016-01-01 00:00:00+00:00              4.38       37.97  311.988  16577.0
# 2016-01-01 01:00:00+00:00              4.57       37.97  311.988  16577.0
# 2016-01-01 02:00:00+00:00              4.68       37.97  311.988  16577.0
# 2016-01-01 03:00:00+00:00              4.62       37.97  311.988  16577.0
# 2016-01-01 04:00:00+00:00              4.46       37.97  311.988  16577.0
# 2016-01-01 05:00:00+00:00              4.28       37.97  311.988  16577.0
# 2016-01-01 06:00:00+00:00              4.08       37.97  311.988  16577.0
# 2016-01-01 07:00:00+00:00              3.84       37.97  311.988  16577.0
# 2016-01-01 08:00:00+00:00              3.72       37.97  311.988  16577.0
# 2016-01-01 09:00:00+00:00              3.68       37.97  311.988  16577.0
# 2016-01-01 10:00:00+00:00              3.56       37.97  311.988  16577.0
# 2016-01-01 11:00:00+00:00              3.31       37.97  311.988  16577.0
# 2016-01-01 12:00:00+00:00              2.87       37.97  311.988  16577.0
# 2016-01-01 13:00:00+00:00              2.36       37.97  311.988  16577.0
# 2016-01-01 14:00:00+00:00              1.92       37.97  311.988  16577.0
# 2016-01-01 15:00:00+00:00              1.55       37.97  311.988  16577.0
# 2016-01-01 16:00:00+00:00              1.49       37.97  311.988  16577.0
# 2016-01-01 17:00:00+00:00              2.01       37.97  311.988  16577.0
# 2016-01-01 18:00:00+00:00              3.00       37.97  311.988  16577.0
# 2016-01-01 19:00:00+00:00              3.75       37.97  311.988  16577.0
# 2016-01-01 20:00:00+00:00              4.41       37.97  311.988  16577.0
# 2016-01-01 21:00:00+00:00              4.99       37.97  311.988  16577.0
# 2016-01-01 22:00:00+00:00              5.65       37.97  311.988  16577.0
# 2016-01-01 23:00:00+00:00              6.36       37.97  311.988  16577.0
# 2016-01-02 00:00:00+00:00              7.08       37.97  311.988  16577.0
# 2016-01-02 01:00:00+00:00              7.66       37.97  311.988  16577.0
# 2016-01-02 02:00:00+00:00              8.37       37.97  311.988  16577.0
# 2016-01-02 03:00:00+00:00              8.99       37.97  311.988  16577.0
# 2016-01-02 04:00:00+00:00              9.72       37.97  311.988  16577.0
# 2016-01-02 05:00:00+00:00             10.43       37.97  311.988  16577.0
# ...                                     ...         ...      ...      ...
# 2016-12-30 18:00:00+00:00              7.93       37.97  311.988  16577.0
# 2016-12-30 19:00:00+00:00              8.04       37.97  311.988  16577.0
# 2016-12-30 20:00:00+00:00              8.18       37.97  311.988  16577.0
# 2016-12-30 21:00:00+00:00              8.34       37.97  311.988  16577.0
# 2016-12-30 22:00:00+00:00              8.43       37.97  311.988  16577.0
# 2016-12-30 23:00:00+00:00              8.48       37.97  311.988  16577.0
# 2016-12-31 00:00:00+00:00              8.49       37.97  311.988  16577.0
# 2016-12-31 01:00:00+00:00              8.50       37.97  311.988  16577.0
# 2016-12-31 02:00:00+00:00              8.56       37.97  311.988  16577.0
# 2016-12-31 03:00:00+00:00              8.69       37.97  311.988  16577.0
# 2016-12-31 04:00:00+00:00              8.81       37.97  311.988  16577.0
# 2016-12-31 05:00:00+00:00              8.93       37.97  311.988  16577.0
# 2016-12-31 06:00:00+00:00              9.12       37.97  311.988  16577.0
# 2016-12-31 07:00:00+00:00              9.23       37.97  311.988  16577.0
# 2016-12-31 08:00:00+00:00              9.37       37.97  311.988  16577.0
# 2016-12-31 09:00:00+00:00              9.52       37.97  311.988  16577.0
# 2016-12-31 10:00:00+00:00              9.64       37.97  311.988  16577.0
# 2016-12-31 11:00:00+00:00              9.65       37.97  311.988  16577.0
# 2016-12-31 12:00:00+00:00              9.62       37.97  311.988  16577.0
# 2016-12-31 13:00:00+00:00              9.50       37.97  311.988  16577.0
# 2016-12-31 14:00:00+00:00              9.29       37.97  311.988  16577.0
# 2016-12-31 15:00:00+00:00              9.12       37.97  311.988  16577.0
# 2016-12-31 16:00:00+00:00              9.01       37.97  311.988  16577.0
# 2016-12-31 17:00:00+00:00              9.11       37.97  311.988  16577.0
# 2016-12-31 18:00:00+00:00              9.28       37.97  311.988  16577.0
# 2016-12-31 19:00:00+00:00              9.52       37.97  311.988  16577.0
# 2016-12-31 20:00:00+00:00              9.74       37.97  311.988  16577.0
# 2016-12-31 21:00:00+00:00              9.93       37.97  311.988  16577.0
# 2016-12-31 22:00:00+00:00              9.98       37.97  311.988  16577.0
# 2016-12-31 23:00:00+00:00             10.12       37.97  311.988  16577.0
#
# [8784 rows x 4 columns]
